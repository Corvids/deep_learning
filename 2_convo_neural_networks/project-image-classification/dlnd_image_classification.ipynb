# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:25, 6.56MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/x.max(axis=0)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return np.eye(10)[x]

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, (None, *image_shape), name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.int32, (None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, (None), name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    input_depth = list(x_tensor.get_shape())[3]
    weights = tf.Variable(tf.truncated_normal(shape=(*conv_ksize, int(input_depth), conv_num_outputs),
                                              stddev=0.01, dtype=tf.float32))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    strides = [1, conv_strides[0], conv_strides[1], 1]
    
    x = tf.nn.conv2d(x_tensor, weights, strides, padding='SAME')
    x = tf.nn.bias_add(x, bias)
    x = tf.nn.elu(x)
    x = tf.nn.max_pool(x, [1, *conv_ksize, 1], [1, *conv_ksize, 1], "SAME")
    
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dimensions = [int(x_tensor.get_shape()[1]), num_outputs]
    weights = tf.Variable(tf.truncated_normal(dimensions, stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    fully_conn_layer = tf.nn.relu(tf.add(tf.matmul(x_tensor, weights), bias))
    return fully_conn_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dimensions = [int(x_tensor.get_shape()[1]), num_outputs]
    weights = tf.Variable(tf.truncated_normal(dimensions, stddev=0.1))
    bias = tf.Variable(tf.zeros([num_outputs]))
    out_layer = tf.add(tf.matmul(x_tensor, weights), bias)
    return out_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_num_outputs = 56
    conv_ksize = (3, 3) 
    conv_strides = (1, 1)
    pool_ksize = (2, 2)
    pool_strides = (2, 2)
    x = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    num_outputs = 256
    x = fully_conn(x, num_outputs)
    x = tf.nn.dropout(x, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    num_outputs = 10
    x = output(x, num_outputs)
    
    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run( optimizer, feed_dict = {x: feature_batch,
                                         y: label_batch,
                                         keep_prob: keep_probability} )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = sess.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    validation_accuracy = sess.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    
    print("Loss: {:>10.3f} Validation Accuracy: {:.6f}".format(loss, validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 40
batch_size = 512
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:      1.984 Validation Accuracy: 0.311400
# Epoch  2, CIFAR-10 Batch 1:  Loss:      1.858 Validation Accuracy: 0.382000
# Epoch  3, CIFAR-10 Batch 1:  Loss:      1.735 Validation Accuracy: 0.406000
# Epoch  4, CIFAR-10 Batch 1:  Loss:      1.651 Validation Accuracy: 0.428800
# Epoch  5, CIFAR-10 Batch 1:  Loss:      1.576 Validation Accuracy: 0.455000
# Epoch  6, CIFAR-10 Batch 1:  Loss:      1.496 Validation Accuracy: 0.469000
# Epoch  7, CIFAR-10 Batch 1:  Loss:      1.413 Validation Accuracy: 0.477600
# Epoch  8, CIFAR-10 Batch 1:  Loss:      1.333 Validation Accuracy: 0.499400
# Epoch  9, CIFAR-10 Batch 1:  Loss:      1.285 Validation Accuracy: 0.503800
# Epoch 10, CIFAR-10 Batch 1:  Loss:      1.198 Validation Accuracy: 0.513600
# Epoch 11, CIFAR-10 Batch 1:  Loss:      1.137 Validation Accuracy: 0.522800
# Epoch 12, CIFAR-10 Batch 1:  Loss:      1.063 Validation Accuracy: 0.529600
# Epoch 13, CIFAR-10 Batch 1:  Loss:      1.016 Validation Accuracy: 0.533200
# Epoch 14, CIFAR-10 Batch 1:  Loss:      0.943 Validation Accuracy: 0.539200
# Epoch 15, CIFAR-10 Batch 1:  Loss:      0.900 Validation Accuracy: 0.546400
# Epoch 16, CIFAR-10 Batch 1:  Loss:      0.872 Validation Accuracy: 0.545200
# Epoch 17, CIFAR-10 Batch 1:  Loss:      0.816 Validation Accuracy: 0.556600
# Epoch 18, CIFAR-10 Batch 1:  Loss:      0.762 Validation Accuracy: 0.558600
# Epoch 19, CIFAR-10 Batch 1:  Loss:      0.719 Validation Accuracy: 0.560800
# Epoch 20, CIFAR-10 Batch 1:  Loss:      0.691 Validation Accuracy: 0.562600
# Epoch 21, CIFAR-10 Batch 1:  Loss:      0.649 Validation Accuracy: 0.563800
# Epoch 22, CIFAR-10 Batch 1:  Loss:      0.604 Validation Accuracy: 0.566800
# Epoch 23, CIFAR-10 Batch 1:  Loss:      0.574 Validation Accuracy: 0.565600
# Epoch 24, CIFAR-10 Batch 1:  Loss:      0.544 Validation Accuracy: 0.578000
# Epoch 25, CIFAR-10 Batch 1:  Loss:      0.513 Validation Accuracy: 0.571200
# Epoch 26, CIFAR-10 Batch 1:  Loss:      0.474 Validation Accuracy: 0.573600
# Epoch 27, CIFAR-10 Batch 1:  Loss:      0.452 Validation Accuracy: 0.568800
# Epoch 28, CIFAR-10 Batch 1:  Loss:      0.434 Validation Accuracy: 0.572600
# Epoch 29, CIFAR-10 Batch 1:  Loss:      0.401 Validation Accuracy: 0.580600
# Epoch 30, CIFAR-10 Batch 1:  Loss:      0.407 Validation Accuracy: 0.562400
# Epoch 31, CIFAR-10 Batch 1:  Loss:      0.354 Validation Accuracy: 0.573000
# Epoch 32, CIFAR-10 Batch 1:  Loss:      0.354 Validation Accuracy: 0.571600
# Epoch 33, CIFAR-10 Batch 1:  Loss:      0.337 Validation Accuracy: 0.565800
# Epoch 34, CIFAR-10 Batch 1:  Loss:      0.312 Validation Accuracy: 0.569800
# Epoch 35, CIFAR-10 Batch 1:  Loss:      0.277 Validation Accuracy: 0.578600
# Epoch 36, CIFAR-10 Batch 1:  Loss:      0.259 Validation Accuracy: 0.574800
# Epoch 37, CIFAR-10 Batch 1:  Loss:      0.240 Validation Accuracy: 0.581200
# Epoch 38, CIFAR-10 Batch 1:  Loss:      0.240 Validation Accuracy: 0.572600
# Epoch 39, CIFAR-10 Batch 1:  Loss:      0.212 Validation Accuracy: 0.578200
# Epoch 40, CIFAR-10 Batch 1:  Loss:      0.200 Validation Accuracy: 0.582000

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:      1.979 Validation Accuracy: 0.318800
# Epoch  1, CIFAR-10 Batch 2:  Loss:      1.765 Validation Accuracy: 0.370000
# Epoch  1, CIFAR-10 Batch 3:  Loss:      1.649 Validation Accuracy: 0.404200
# Epoch  1, CIFAR-10 Batch 4:  Loss:      1.573 Validation Accuracy: 0.413000
# Epoch  1, CIFAR-10 Batch 5:  Loss:      1.597 Validation Accuracy: 0.443200
# Epoch  2, CIFAR-10 Batch 1:  Loss:      1.590 Validation Accuracy: 0.468600
# Epoch  2, CIFAR-10 Batch 2:  Loss:      1.425 Validation Accuracy: 0.495000
# Epoch  2, CIFAR-10 Batch 3:  Loss:      1.327 Validation Accuracy: 0.500200
# Epoch  2, CIFAR-10 Batch 4:  Loss:      1.298 Validation Accuracy: 0.508400
# Epoch  2, CIFAR-10 Batch 5:  Loss:      1.335 Validation Accuracy: 0.521600
# Epoch  3, CIFAR-10 Batch 1:  Loss:      1.386 Validation Accuracy: 0.530200
# Epoch  3, CIFAR-10 Batch 2:  Loss:      1.225 Validation Accuracy: 0.545000
# Epoch  3, CIFAR-10 Batch 3:  Loss:      1.165 Validation Accuracy: 0.546400
# Epoch  3, CIFAR-10 Batch 4:  Loss:      1.150 Validation Accuracy: 0.552000
# Epoch  3, CIFAR-10 Batch 5:  Loss:      1.189 Validation Accuracy: 0.558400
# Epoch  4, CIFAR-10 Batch 1:  Loss:      1.252 Validation Accuracy: 0.558600
# Epoch  4, CIFAR-10 Batch 2:  Loss:      1.104 Validation Accuracy: 0.574600
# Epoch  4, CIFAR-10 Batch 3:  Loss:      1.062 Validation Accuracy: 0.570600
# Epoch  4, CIFAR-10 Batch 4:  Loss:      1.066 Validation Accuracy: 0.567600
# Epoch  4, CIFAR-10 Batch 5:  Loss:      1.092 Validation Accuracy: 0.574600
# Epoch  5, CIFAR-10 Batch 1:  Loss:      1.189 Validation Accuracy: 0.579000
# Epoch  5, CIFAR-10 Batch 2:  Loss:      1.020 Validation Accuracy: 0.586800
# Epoch  5, CIFAR-10 Batch 3:  Loss:      0.985 Validation Accuracy: 0.589400
# Epoch  5, CIFAR-10 Batch 4:  Loss:      0.978 Validation Accuracy: 0.586800
# Epoch  5, CIFAR-10 Batch 5:  Loss:      0.998 Validation Accuracy: 0.593400
# Epoch  6, CIFAR-10 Batch 1:  Loss:      1.089 Validation Accuracy: 0.591200
# Epoch  6, CIFAR-10 Batch 2:  Loss:      0.965 Validation Accuracy: 0.599400
# Epoch  6, CIFAR-10 Batch 3:  Loss:      0.922 Validation Accuracy: 0.604600
# Epoch  6, CIFAR-10 Batch 4:  Loss:      0.920 Validation Accuracy: 0.600200
# Epoch  6, CIFAR-10 Batch 5:  Loss:      0.925 Validation Accuracy: 0.607400
# Epoch  7, CIFAR-10 Batch 1:  Loss:      1.031 Validation Accuracy: 0.602600
# Epoch  7, CIFAR-10 Batch 2:  Loss:      0.899 Validation Accuracy: 0.612400
# Epoch  7, CIFAR-10 Batch 3:  Loss:      0.865 Validation Accuracy: 0.608400
# Epoch  7, CIFAR-10 Batch 4:  Loss:      0.844 Validation Accuracy: 0.610400
# Epoch  7, CIFAR-10 Batch 5:  Loss:      0.903 Validation Accuracy: 0.608600
# Epoch  8, CIFAR-10 Batch 1:  Loss:      0.965 Validation Accuracy: 0.617400
# Epoch  8, CIFAR-10 Batch 2:  Loss:      0.869 Validation Accuracy: 0.625000
# Epoch  8, CIFAR-10 Batch 3:  Loss:      0.790 Validation Accuracy: 0.617200
# Epoch  8, CIFAR-10 Batch 4:  Loss:      0.796 Validation Accuracy: 0.627200
# Epoch  8, CIFAR-10 Batch 5:  Loss:      0.826 Validation Accuracy: 0.626200
# Epoch  9, CIFAR-10 Batch 1:  Loss:      0.913 Validation Accuracy: 0.629200
# Epoch  9, CIFAR-10 Batch 2:  Loss:      0.820 Validation Accuracy: 0.632400
# Epoch  9, CIFAR-10 Batch 3:  Loss:      0.757 Validation Accuracy: 0.625600
# Epoch  9, CIFAR-10 Batch 4:  Loss:      0.748 Validation Accuracy: 0.631800
# Epoch  9, CIFAR-10 Batch 5:  Loss:      0.762 Validation Accuracy: 0.634600
# Epoch 10, CIFAR-10 Batch 1:  Loss:      0.863 Validation Accuracy: 0.636600
# Epoch 10, CIFAR-10 Batch 2:  Loss:      0.743 Validation Accuracy: 0.642400
# Epoch 10, CIFAR-10 Batch 3:  Loss:      0.707 Validation Accuracy: 0.639200
# Epoch 10, CIFAR-10 Batch 4:  Loss:      0.698 Validation Accuracy: 0.641800
# Epoch 10, CIFAR-10 Batch 5:  Loss:      0.724 Validation Accuracy: 0.639200
# Epoch 11, CIFAR-10 Batch 1:  Loss:      0.816 Validation Accuracy: 0.641000
# Epoch 11, CIFAR-10 Batch 2:  Loss:      0.728 Validation Accuracy: 0.638800
# Epoch 11, CIFAR-10 Batch 3:  Loss:      0.682 Validation Accuracy: 0.646600
# Epoch 11, CIFAR-10 Batch 4:  Loss:      0.652 Validation Accuracy: 0.646000
# Epoch 11, CIFAR-10 Batch 5:  Loss:      0.669 Validation Accuracy: 0.646000
# Epoch 12, CIFAR-10 Batch 1:  Loss:      0.758 Validation Accuracy: 0.653600
# Epoch 12, CIFAR-10 Batch 2:  Loss:      0.682 Validation Accuracy: 0.648800
# Epoch 12, CIFAR-10 Batch 3:  Loss:      0.642 Validation Accuracy: 0.651000
# Epoch 12, CIFAR-10 Batch 4:  Loss:      0.628 Validation Accuracy: 0.644800
# Epoch 12, CIFAR-10 Batch 5:  Loss:      0.656 Validation Accuracy: 0.645400
# Epoch 13, CIFAR-10 Batch 1:  Loss:      0.703 Validation Accuracy: 0.656400
# Epoch 13, CIFAR-10 Batch 2:  Loss:      0.635 Validation Accuracy: 0.657000
# Epoch 13, CIFAR-10 Batch 3:  Loss:      0.601 Validation Accuracy: 0.657600
# Epoch 13, CIFAR-10 Batch 4:  Loss:      0.574 Validation Accuracy: 0.658600
# Epoch 13, CIFAR-10 Batch 5:  Loss:      0.602 Validation Accuracy: 0.655600
# Epoch 14, CIFAR-10 Batch 1:  Loss:      0.665 Validation Accuracy: 0.662000
# Epoch 14, CIFAR-10 Batch 2:  Loss:      0.608 Validation Accuracy: 0.665800
# Epoch 14, CIFAR-10 Batch 3:  Loss:      0.573 Validation Accuracy: 0.662200
# Epoch 14, CIFAR-10 Batch 4:  Loss:      0.547 Validation Accuracy: 0.663600
# Epoch 14, CIFAR-10 Batch 5:  Loss:      0.559 Validation Accuracy: 0.658400
# Epoch 15, CIFAR-10 Batch 1:  Loss:      0.646 Validation Accuracy: 0.662000
# Epoch 15, CIFAR-10 Batch 2:  Loss:      0.586 Validation Accuracy: 0.658800
# Epoch 15, CIFAR-10 Batch 3:  Loss:      0.562 Validation Accuracy: 0.663200
# Epoch 15, CIFAR-10 Batch 4:  Loss:      0.540 Validation Accuracy: 0.666400
# Epoch 15, CIFAR-10 Batch 5:  Loss:      0.541 Validation Accuracy: 0.666200
# Epoch 16, CIFAR-10 Batch 1:  Loss:      0.626 Validation Accuracy: 0.669200
# Epoch 16, CIFAR-10 Batch 2:  Loss:      0.562 Validation Accuracy: 0.654600
# Epoch 16, CIFAR-10 Batch 3:  Loss:      0.518 Validation Accuracy: 0.670200
# Epoch 16, CIFAR-10 Batch 4:  Loss:      0.522 Validation Accuracy: 0.671400
# Epoch 16, CIFAR-10 Batch 5:  Loss:      0.501 Validation Accuracy: 0.669400
# Epoch 17, CIFAR-10 Batch 1:  Loss:      0.575 Validation Accuracy: 0.673000
# Epoch 17, CIFAR-10 Batch 2:  Loss:      0.532 Validation Accuracy: 0.672600
# Epoch 17, CIFAR-10 Batch 3:  Loss:      0.500 Validation Accuracy: 0.674800
# Epoch 17, CIFAR-10 Batch 4:  Loss:      0.490 Validation Accuracy: 0.672000
# Epoch 17, CIFAR-10 Batch 5:  Loss:      0.471 Validation Accuracy: 0.676000
# Epoch 18, CIFAR-10 Batch 1:  Loss:      0.544 Validation Accuracy: 0.676200
# Epoch 18, CIFAR-10 Batch 2:  Loss:      0.475 Validation Accuracy: 0.675800
# Epoch 18, CIFAR-10 Batch 3:  Loss:      0.460 Validation Accuracy: 0.678400
# Epoch 18, CIFAR-10 Batch 4:  Loss:      0.440 Validation Accuracy: 0.677600
# Epoch 18, CIFAR-10 Batch 5:  Loss:      0.430 Validation Accuracy: 0.676000
# Epoch 19, CIFAR-10 Batch 1:  Loss:      0.524 Validation Accuracy: 0.677400
# Epoch 19, CIFAR-10 Batch 2:  Loss:      0.463 Validation Accuracy: 0.678200
# Epoch 19, CIFAR-10 Batch 3:  Loss:      0.436 Validation Accuracy: 0.678400
# Epoch 19, CIFAR-10 Batch 4:  Loss:      0.425 Validation Accuracy: 0.683200
# Epoch 19, CIFAR-10 Batch 5:  Loss:      0.423 Validation Accuracy: 0.677000
# Epoch 20, CIFAR-10 Batch 1:  Loss:      0.491 Validation Accuracy: 0.677400
# Epoch 20, CIFAR-10 Batch 2:  Loss:      0.454 Validation Accuracy: 0.680800
# Epoch 20, CIFAR-10 Batch 3:  Loss:      0.415 Validation Accuracy: 0.672600
# Epoch 20, CIFAR-10 Batch 4:  Loss:      0.414 Validation Accuracy: 0.683600
# Epoch 20, CIFAR-10 Batch 5:  Loss:      0.399 Validation Accuracy: 0.674000
# Epoch 21, CIFAR-10 Batch 1:  Loss:      0.476 Validation Accuracy: 0.680600
# Epoch 21, CIFAR-10 Batch 2:  Loss:      0.432 Validation Accuracy: 0.680000
# Epoch 21, CIFAR-10 Batch 3:  Loss:      0.397 Validation Accuracy: 0.675400
# Epoch 21, CIFAR-10 Batch 4:  Loss:      0.384 Validation Accuracy: 0.676800
# Epoch 21, CIFAR-10 Batch 5:  Loss:      0.381 Validation Accuracy: 0.674200
# Epoch 22, CIFAR-10 Batch 1:  Loss:      0.464 Validation Accuracy: 0.680200
# Epoch 22, CIFAR-10 Batch 2:  Loss:      0.396 Validation Accuracy: 0.683000
# Epoch 22, CIFAR-10 Batch 3:  Loss:      0.376 Validation Accuracy: 0.683000
# Epoch 22, CIFAR-10 Batch 4:  Loss:      0.359 Validation Accuracy: 0.681600
# Epoch 22, CIFAR-10 Batch 5:  Loss:      0.342 Validation Accuracy: 0.685800
# Epoch 23, CIFAR-10 Batch 1:  Loss:      0.426 Validation Accuracy: 0.682600
# Epoch 23, CIFAR-10 Batch 2:  Loss:      0.410 Validation Accuracy: 0.678600
# Epoch 23, CIFAR-10 Batch 3:  Loss:      0.373 Validation Accuracy: 0.681000
# Epoch 23, CIFAR-10 Batch 4:  Loss:      0.334 Validation Accuracy: 0.687000
# Epoch 23, CIFAR-10 Batch 5:  Loss:      0.331 Validation Accuracy: 0.683200
# Epoch 24, CIFAR-10 Batch 1:  Loss:      0.402 Validation Accuracy: 0.687600
# Epoch 24, CIFAR-10 Batch 2:  Loss:      0.372 Validation Accuracy: 0.686200
# Epoch 24, CIFAR-10 Batch 3:  Loss:      0.342 Validation Accuracy: 0.686600
# Epoch 24, CIFAR-10 Batch 4:  Loss:      0.332 Validation Accuracy: 0.682200
# Epoch 24, CIFAR-10 Batch 5:  Loss:      0.323 Validation Accuracy: 0.670000
# Epoch 25, CIFAR-10 Batch 1:  Loss:      0.371 Validation Accuracy: 0.684000
# Epoch 25, CIFAR-10 Batch 2:  Loss:      0.390 Validation Accuracy: 0.667400
# Epoch 25, CIFAR-10 Batch 3:  Loss:      0.328 Validation Accuracy: 0.685600
# Epoch 25, CIFAR-10 Batch 4:  Loss:      0.311 Validation Accuracy: 0.684800
# Epoch 25, CIFAR-10 Batch 5:  Loss:      0.282 Validation Accuracy: 0.680600
# Epoch 26, CIFAR-10 Batch 1:  Loss:      0.368 Validation Accuracy: 0.676400
# Epoch 26, CIFAR-10 Batch 2:  Loss:      0.356 Validation Accuracy: 0.674000
# Epoch 26, CIFAR-10 Batch 3:  Loss:      0.332 Validation Accuracy: 0.683800
# Epoch 26, CIFAR-10 Batch 4:  Loss:      0.335 Validation Accuracy: 0.676600
# Epoch 26, CIFAR-10 Batch 5:  Loss:      0.268 Validation Accuracy: 0.687200
# Epoch 27, CIFAR-10 Batch 1:  Loss:      0.327 Validation Accuracy: 0.683800
# Epoch 27, CIFAR-10 Batch 2:  Loss:      0.302 Validation Accuracy: 0.690800
# Epoch 27, CIFAR-10 Batch 3:  Loss:      0.293 Validation Accuracy: 0.689800
# Epoch 27, CIFAR-10 Batch 4:  Loss:      0.295 Validation Accuracy: 0.679800
# Epoch 27, CIFAR-10 Batch 5:  Loss:      0.263 Validation Accuracy: 0.684000
# Epoch 28, CIFAR-10 Batch 1:  Loss:      0.302 Validation Accuracy: 0.686200
# Epoch 28, CIFAR-10 Batch 2:  Loss:      0.297 Validation Accuracy: 0.696400
# Epoch 28, CIFAR-10 Batch 3:  Loss:      0.268 Validation Accuracy: 0.693200
# Epoch 28, CIFAR-10 Batch 4:  Loss:      0.280 Validation Accuracy: 0.683800
# Epoch 28, CIFAR-10 Batch 5:  Loss:      0.265 Validation Accuracy: 0.690400
# Epoch 29, CIFAR-10 Batch 1:  Loss:      0.284 Validation Accuracy: 0.689200
# Epoch 29, CIFAR-10 Batch 2:  Loss:      0.287 Validation Accuracy: 0.694600
# Epoch 29, CIFAR-10 Batch 3:  Loss:      0.261 Validation Accuracy: 0.691800
# Epoch 29, CIFAR-10 Batch 4:  Loss:      0.268 Validation Accuracy: 0.684000
# Epoch 29, CIFAR-10 Batch 5:  Loss:      0.266 Validation Accuracy: 0.682200
# Epoch 30, CIFAR-10 Batch 1:  Loss:      0.283 Validation Accuracy: 0.680000
# Epoch 30, CIFAR-10 Batch 2:  Loss:      0.260 Validation Accuracy: 0.692200
# Epoch 30, CIFAR-10 Batch 3:  Loss:      0.262 Validation Accuracy: 0.681400
# Epoch 30, CIFAR-10 Batch 4:  Loss:      0.248 Validation Accuracy: 0.688600
# Epoch 30, CIFAR-10 Batch 5:  Loss:      0.239 Validation Accuracy: 0.683400
# Epoch 31, CIFAR-10 Batch 1:  Loss:      0.269 Validation Accuracy: 0.691400
# Epoch 31, CIFAR-10 Batch 2:  Loss:      0.249 Validation Accuracy: 0.693000
# Epoch 31, CIFAR-10 Batch 3:  Loss:      0.246 Validation Accuracy: 0.695600
# Epoch 31, CIFAR-10 Batch 4:  Loss:      0.227 Validation Accuracy: 0.684200
# Epoch 31, CIFAR-10 Batch 5:  Loss:      0.220 Validation Accuracy: 0.687800
# Epoch 32, CIFAR-10 Batch 1:  Loss:      0.234 Validation Accuracy: 0.693000
# Epoch 32, CIFAR-10 Batch 2:  Loss:      0.250 Validation Accuracy: 0.695400
# Epoch 32, CIFAR-10 Batch 3:  Loss:      0.224 Validation Accuracy: 0.685400
# Epoch 32, CIFAR-10 Batch 4:  Loss:      0.210 Validation Accuracy: 0.690400
# Epoch 32, CIFAR-10 Batch 5:  Loss:      0.218 Validation Accuracy: 0.686800
# Epoch 33, CIFAR-10 Batch 1:  Loss:      0.222 Validation Accuracy: 0.691200
# Epoch 33, CIFAR-10 Batch 2:  Loss:      0.243 Validation Accuracy: 0.688800
# Epoch 33, CIFAR-10 Batch 3:  Loss:      0.217 Validation Accuracy: 0.693000
# Epoch 33, CIFAR-10 Batch 4:  Loss:      0.198 Validation Accuracy: 0.686000
# Epoch 33, CIFAR-10 Batch 5:  Loss:      0.207 Validation Accuracy: 0.685400
# Epoch 34, CIFAR-10 Batch 1:  Loss:      0.224 Validation Accuracy: 0.694800
# Epoch 34, CIFAR-10 Batch 2:  Loss:      0.224 Validation Accuracy: 0.698800
# Epoch 34, CIFAR-10 Batch 3:  Loss:      0.193 Validation Accuracy: 0.693200
# Epoch 34, CIFAR-10 Batch 4:  Loss:      0.184 Validation Accuracy: 0.687800
# Epoch 34, CIFAR-10 Batch 5:  Loss:      0.218 Validation Accuracy: 0.684400
# Epoch 35, CIFAR-10 Batch 1:  Loss:      0.222 Validation Accuracy: 0.697400
# Epoch 35, CIFAR-10 Batch 2:  Loss:      0.205 Validation Accuracy: 0.698000
# Epoch 35, CIFAR-10 Batch 3:  Loss:      0.196 Validation Accuracy: 0.689200
# Epoch 35, CIFAR-10 Batch 4:  Loss:      0.174 Validation Accuracy: 0.689000
# Epoch 35, CIFAR-10 Batch 5:  Loss:      0.172 Validation Accuracy: 0.688200
# Epoch 36, CIFAR-10 Batch 1:  Loss:      0.202 Validation Accuracy: 0.694800
# Epoch 36, CIFAR-10 Batch 2:  Loss:      0.196 Validation Accuracy: 0.697000
# Epoch 36, CIFAR-10 Batch 3:  Loss:      0.194 Validation Accuracy: 0.686600
# Epoch 36, CIFAR-10 Batch 4:  Loss:      0.163 Validation Accuracy: 0.686600
# Epoch 36, CIFAR-10 Batch 5:  Loss:      0.172 Validation Accuracy: 0.691200
# Epoch 37, CIFAR-10 Batch 1:  Loss:      0.192 Validation Accuracy: 0.695600
# Epoch 37, CIFAR-10 Batch 2:  Loss:      0.185 Validation Accuracy: 0.694400
# Epoch 37, CIFAR-10 Batch 3:  Loss:      0.177 Validation Accuracy: 0.683400
# Epoch 37, CIFAR-10 Batch 4:  Loss:      0.168 Validation Accuracy: 0.688800
# Epoch 37, CIFAR-10 Batch 5:  Loss:      0.157 Validation Accuracy: 0.692800
# Epoch 38, CIFAR-10 Batch 1:  Loss:      0.194 Validation Accuracy: 0.698200
# Epoch 38, CIFAR-10 Batch 2:  Loss:      0.181 Validation Accuracy: 0.698200
# Epoch 38, CIFAR-10 Batch 3:  Loss:      0.162 Validation Accuracy: 0.693600
# Epoch 38, CIFAR-10 Batch 4:  Loss:      0.154 Validation Accuracy: 0.692800
# Epoch 38, CIFAR-10 Batch 5:  Loss:      0.154 Validation Accuracy: 0.690800
# Epoch 39, CIFAR-10 Batch 1:  Loss:      0.174 Validation Accuracy: 0.699800
# Epoch 39, CIFAR-10 Batch 2:  Loss:      0.179 Validation Accuracy: 0.693200
# Epoch 39, CIFAR-10 Batch 3:  Loss:      0.170 Validation Accuracy: 0.687800
# Epoch 39, CIFAR-10 Batch 4:  Loss:      0.152 Validation Accuracy: 0.692600
# Epoch 39, CIFAR-10 Batch 5:  Loss:      0.136 Validation Accuracy: 0.691600
# Epoch 40, CIFAR-10 Batch 1:  Loss:      0.164 Validation Accuracy: 0.698800
# Epoch 40, CIFAR-10 Batch 2:  Loss:      0.163 Validation Accuracy: 0.696600
# Epoch 40, CIFAR-10 Batch 3:  Loss:      0.150 Validation Accuracy: 0.694000
# Epoch 40, CIFAR-10 Batch 4:  Loss:      0.137 Validation Accuracy: 0.695800
# Epoch 40, CIFAR-10 Batch 5:  Loss:      0.116 Validation Accuracy: 0.694200

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6937959551811218

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
