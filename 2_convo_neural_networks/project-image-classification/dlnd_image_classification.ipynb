# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:26, 6.36MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/x.max(axis=0)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return np.eye(10)[x]

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, (None, *image_shape), name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.int32, (None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, (None), name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    input_depth = list(x_tensor.get_shape())[3]
    weights = tf.Variable(tf.truncated_normal(shape=(*conv_ksize, int(input_depth), conv_num_outputs),
                                              stddev=0.01, dtype=tf.float32))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    strides = [1, conv_strides[0], conv_strides[1], 1]
    
    x = tf.nn.conv2d(x_tensor, weights, strides, padding='SAME')
    x = tf.nn.bias_add(x, bias)
    x = tf.nn.elu(x)
    x = tf.nn.max_pool(x, [1, *conv_ksize, 1], [1, *conv_ksize, 1], "SAME")
    
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dimensions = [int(x_tensor.get_shape()[1]), num_outputs]
    weights = tf.Variable(tf.truncated_normal(dimensions, stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    fully_conn_layer = tf.nn.relu(tf.add(tf.matmul(x_tensor, weights), bias))
    return fully_conn_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    dimensions = [int(x_tensor.get_shape()[1]), num_outputs]
    weights = tf.Variable(tf.truncated_normal(dimensions, stddev=0.1))
    bias = tf.Variable(tf.zeros([num_outputs]))
    out_layer = tf.add(tf.matmul(x_tensor, weights), bias)
    return out_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_num_outputs = 56
    conv_ksize = (3, 3) 
    conv_strides = (1, 1)
    pool_ksize = (2, 2)
    pool_strides = (2, 2)
    x = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    num_outputs = 256
    x = fully_conn(x, num_outputs)
    x = tf.nn.dropout(x, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    num_outputs = 10
    x = fully_conn(x, num_outputs)
    
    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run( optimizer, feed_dict = {x: feature_batch,
                                         y: label_batch,
                                         keep_prob: keep_probability} )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = sess.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    validation_accuracy = sess.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    
    print("Loss: {:>10.3f} Validation Accuracy: {:.6f}".format(loss, validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 512
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:      2.107 Validation Accuracy: 0.291800
# Epoch  2, CIFAR-10 Batch 1:  Loss:      1.898 Validation Accuracy: 0.375000
# Epoch  3, CIFAR-10 Batch 1:  Loss:      1.754 Validation Accuracy: 0.409200
# Epoch  4, CIFAR-10 Batch 1:  Loss:      1.692 Validation Accuracy: 0.417800
# Epoch  5, CIFAR-10 Batch 1:  Loss:      1.581 Validation Accuracy: 0.442600
# Epoch  6, CIFAR-10 Batch 1:  Loss:      1.523 Validation Accuracy: 0.456600
# Epoch  7, CIFAR-10 Batch 1:  Loss:      1.448 Validation Accuracy: 0.466200
# Epoch  8, CIFAR-10 Batch 1:  Loss:      1.376 Validation Accuracy: 0.487200
# Epoch  9, CIFAR-10 Batch 1:  Loss:      1.284 Validation Accuracy: 0.505200
# Epoch 10, CIFAR-10 Batch 1:  Loss:      1.226 Validation Accuracy: 0.509800
# Epoch 11, CIFAR-10 Batch 1:  Loss:      1.160 Validation Accuracy: 0.517600
# Epoch 12, CIFAR-10 Batch 1:  Loss:      1.108 Validation Accuracy: 0.513000
# Epoch 13, CIFAR-10 Batch 1:  Loss:      1.042 Validation Accuracy: 0.536400
# Epoch 14, CIFAR-10 Batch 1:  Loss:      1.003 Validation Accuracy: 0.546200
# Epoch 15, CIFAR-10 Batch 1:  Loss:      0.931 Validation Accuracy: 0.539200
# Epoch 16, CIFAR-10 Batch 1:  Loss:      0.882 Validation Accuracy: 0.547400
# Epoch 17, CIFAR-10 Batch 1:  Loss:      0.843 Validation Accuracy: 0.548400
# Epoch 18, CIFAR-10 Batch 1:  Loss:      0.801 Validation Accuracy: 0.547400
# Epoch 19, CIFAR-10 Batch 1:  Loss:      0.774 Validation Accuracy: 0.551200
# Epoch 20, CIFAR-10 Batch 1:  Loss:      0.716 Validation Accuracy: 0.556400
# Epoch 21, CIFAR-10 Batch 1:  Loss:      0.672 Validation Accuracy: 0.561600
# Epoch 22, CIFAR-10 Batch 1:  Loss:      0.649 Validation Accuracy: 0.561600
# Epoch 23, CIFAR-10 Batch 1:  Loss:      0.605 Validation Accuracy: 0.559200
# Epoch 24, CIFAR-10 Batch 1:  Loss:      0.566 Validation Accuracy: 0.561600
# Epoch 25, CIFAR-10 Batch 1:  Loss:      0.538 Validation Accuracy: 0.561800
# Epoch 26, CIFAR-10 Batch 1:  Loss:      0.510 Validation Accuracy: 0.558000
# Epoch 27, CIFAR-10 Batch 1:  Loss:      0.543 Validation Accuracy: 0.542400
# Epoch 28, CIFAR-10 Batch 1:  Loss:      0.458 Validation Accuracy: 0.570000
# Epoch 29, CIFAR-10 Batch 1:  Loss:      0.445 Validation Accuracy: 0.570600
# Epoch 30, CIFAR-10 Batch 1:  Loss:      0.421 Validation Accuracy: 0.556000
# Epoch 31, CIFAR-10 Batch 1:  Loss:      0.401 Validation Accuracy: 0.571800
# Epoch 32, CIFAR-10 Batch 1:  Loss:      0.369 Validation Accuracy: 0.567000
# Epoch 33, CIFAR-10 Batch 1:  Loss:      0.359 Validation Accuracy: 0.560600
# Epoch 34, CIFAR-10 Batch 1:  Loss:      0.329 Validation Accuracy: 0.565000
# Epoch 35, CIFAR-10 Batch 1:  Loss:      0.323 Validation Accuracy: 0.559800
# Epoch 36, CIFAR-10 Batch 1:  Loss:      0.309 Validation Accuracy: 0.560400
# Epoch 37, CIFAR-10 Batch 1:  Loss:      0.300 Validation Accuracy: 0.576400
# Epoch 38, CIFAR-10 Batch 1:  Loss:      0.315 Validation Accuracy: 0.566000
# Epoch 39, CIFAR-10 Batch 1:  Loss:      0.260 Validation Accuracy: 0.576400
# Epoch 40, CIFAR-10 Batch 1:  Loss:      0.248 Validation Accuracy: 0.567600
# Epoch 41, CIFAR-10 Batch 1:  Loss:      0.224 Validation Accuracy: 0.573800
# Epoch 42, CIFAR-10 Batch 1:  Loss:      0.225 Validation Accuracy: 0.574400
# Epoch 43, CIFAR-10 Batch 1:  Loss:      0.214 Validation Accuracy: 0.572000
# Epoch 44, CIFAR-10 Batch 1:  Loss:      0.190 Validation Accuracy: 0.575200
# Epoch 45, CIFAR-10 Batch 1:  Loss:      0.211 Validation Accuracy: 0.573400
# Epoch 46, CIFAR-10 Batch 1:  Loss:      0.179 Validation Accuracy: 0.579600
# Epoch 47, CIFAR-10 Batch 1:  Loss:      0.157 Validation Accuracy: 0.580000
# Epoch 48, CIFAR-10 Batch 1:  Loss:      0.147 Validation Accuracy: 0.574000
# Epoch 49, CIFAR-10 Batch 1:  Loss:      0.134 Validation Accuracy: 0.581600
# Epoch 50, CIFAR-10 Batch 1:  Loss:      0.130 Validation Accuracy: 0.583800

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:      2.138 Validation Accuracy: 0.263200
# Epoch  1, CIFAR-10 Batch 2:  Loss:      1.861 Validation Accuracy: 0.335600
# Epoch  1, CIFAR-10 Batch 3:  Loss:      1.659 Validation Accuracy: 0.390600
# Epoch  1, CIFAR-10 Batch 4:  Loss:      1.597 Validation Accuracy: 0.413200
# Epoch  1, CIFAR-10 Batch 5:  Loss:      1.618 Validation Accuracy: 0.444600
# Epoch  2, CIFAR-10 Batch 1:  Loss:      1.639 Validation Accuracy: 0.467200
# Epoch  2, CIFAR-10 Batch 2:  Loss:      1.462 Validation Accuracy: 0.487000
# Epoch  2, CIFAR-10 Batch 3:  Loss:      1.335 Validation Accuracy: 0.489200
# Epoch  2, CIFAR-10 Batch 4:  Loss:      1.328 Validation Accuracy: 0.494200
# Epoch  2, CIFAR-10 Batch 5:  Loss:      1.333 Validation Accuracy: 0.517200
# Epoch  3, CIFAR-10 Batch 1:  Loss:      1.402 Validation Accuracy: 0.532800
# Epoch  3, CIFAR-10 Batch 2:  Loss:      1.242 Validation Accuracy: 0.545200
# Epoch  3, CIFAR-10 Batch 3:  Loss:      1.177 Validation Accuracy: 0.539200
# Epoch  3, CIFAR-10 Batch 4:  Loss:      1.135 Validation Accuracy: 0.552000
# Epoch  3, CIFAR-10 Batch 5:  Loss:      1.175 Validation Accuracy: 0.558600
# Epoch  4, CIFAR-10 Batch 1:  Loss:      1.271 Validation Accuracy: 0.566200
# Epoch  4, CIFAR-10 Batch 2:  Loss:      1.114 Validation Accuracy: 0.571400
# Epoch  4, CIFAR-10 Batch 3:  Loss:      1.047 Validation Accuracy: 0.571000
# Epoch  4, CIFAR-10 Batch 4:  Loss:      1.036 Validation Accuracy: 0.577000
# Epoch  4, CIFAR-10 Batch 5:  Loss:      1.061 Validation Accuracy: 0.581800
# Epoch  5, CIFAR-10 Batch 1:  Loss:      1.160 Validation Accuracy: 0.575800
# Epoch  5, CIFAR-10 Batch 2:  Loss:      1.018 Validation Accuracy: 0.595800
# Epoch  5, CIFAR-10 Batch 3:  Loss:      0.975 Validation Accuracy: 0.582600
# Epoch  5, CIFAR-10 Batch 4:  Loss:      0.964 Validation Accuracy: 0.587800
# Epoch  5, CIFAR-10 Batch 5:  Loss:      0.991 Validation Accuracy: 0.595200
# Epoch  6, CIFAR-10 Batch 1:  Loss:      1.086 Validation Accuracy: 0.600400
# Epoch  6, CIFAR-10 Batch 2:  Loss:      0.952 Validation Accuracy: 0.613200
# Epoch  6, CIFAR-10 Batch 3:  Loss:      0.880 Validation Accuracy: 0.612400
# Epoch  6, CIFAR-10 Batch 4:  Loss:      0.866 Validation Accuracy: 0.608200
# Epoch  6, CIFAR-10 Batch 5:  Loss:      0.915 Validation Accuracy: 0.613400
# Epoch  7, CIFAR-10 Batch 1:  Loss:      1.024 Validation Accuracy: 0.616200
# Epoch  7, CIFAR-10 Batch 2:  Loss:      0.895 Validation Accuracy: 0.621000
# Epoch  7, CIFAR-10 Batch 3:  Loss:      0.838 Validation Accuracy: 0.615400
# Epoch  7, CIFAR-10 Batch 4:  Loss:      0.814 Validation Accuracy: 0.618400
# Epoch  7, CIFAR-10 Batch 5:  Loss:      0.863 Validation Accuracy: 0.619400
# Epoch  8, CIFAR-10 Batch 1:  Loss:      0.947 Validation Accuracy: 0.627800
# Epoch  8, CIFAR-10 Batch 2:  Loss:      0.850 Validation Accuracy: 0.633600
# Epoch  8, CIFAR-10 Batch 3:  Loss:      0.790 Validation Accuracy: 0.625000
# Epoch  8, CIFAR-10 Batch 4:  Loss:      0.756 Validation Accuracy: 0.628400
# Epoch  8, CIFAR-10 Batch 5:  Loss:      0.804 Validation Accuracy: 0.630400
# Epoch  9, CIFAR-10 Batch 1:  Loss:      0.906 Validation Accuracy: 0.630600
# Epoch  9, CIFAR-10 Batch 2:  Loss:      0.785 Validation Accuracy: 0.640000
# Epoch  9, CIFAR-10 Batch 3:  Loss:      0.728 Validation Accuracy: 0.639600
# Epoch  9, CIFAR-10 Batch 4:  Loss:      0.727 Validation Accuracy: 0.638000
# Epoch  9, CIFAR-10 Batch 5:  Loss:      0.743 Validation Accuracy: 0.643200
# Epoch 10, CIFAR-10 Batch 1:  Loss:      0.854 Validation Accuracy: 0.636800
# Epoch 10, CIFAR-10 Batch 2:  Loss:      0.754 Validation Accuracy: 0.637200
# Epoch 10, CIFAR-10 Batch 3:  Loss:      0.694 Validation Accuracy: 0.644200
# Epoch 10, CIFAR-10 Batch 4:  Loss:      0.669 Validation Accuracy: 0.646600
# Epoch 10, CIFAR-10 Batch 5:  Loss:      0.720 Validation Accuracy: 0.632800
# Epoch 11, CIFAR-10 Batch 1:  Loss:      0.788 Validation Accuracy: 0.652800
# Epoch 11, CIFAR-10 Batch 2:  Loss:      0.720 Validation Accuracy: 0.648400
# Epoch 11, CIFAR-10 Batch 3:  Loss:      0.658 Validation Accuracy: 0.652400
# Epoch 11, CIFAR-10 Batch 4:  Loss:      0.647 Validation Accuracy: 0.659600
# Epoch 11, CIFAR-10 Batch 5:  Loss:      0.647 Validation Accuracy: 0.657200
# Epoch 12, CIFAR-10 Batch 1:  Loss:      0.762 Validation Accuracy: 0.655600
# Epoch 12, CIFAR-10 Batch 2:  Loss:      0.676 Validation Accuracy: 0.663600
# Epoch 12, CIFAR-10 Batch 3:  Loss:      0.624 Validation Accuracy: 0.658800
# Epoch 12, CIFAR-10 Batch 4:  Loss:      0.615 Validation Accuracy: 0.659000
# Epoch 12, CIFAR-10 Batch 5:  Loss:      0.620 Validation Accuracy: 0.656000
# Epoch 13, CIFAR-10 Batch 1:  Loss:      0.710 Validation Accuracy: 0.658000
# Epoch 13, CIFAR-10 Batch 2:  Loss:      0.625 Validation Accuracy: 0.666800
# Epoch 13, CIFAR-10 Batch 3:  Loss:      0.607 Validation Accuracy: 0.662200
# Epoch 13, CIFAR-10 Batch 4:  Loss:      0.576 Validation Accuracy: 0.657600
# Epoch 13, CIFAR-10 Batch 5:  Loss:      0.570 Validation Accuracy: 0.662600
# Epoch 14, CIFAR-10 Batch 1:  Loss:      0.672 Validation Accuracy: 0.670800
# Epoch 14, CIFAR-10 Batch 2:  Loss:      0.602 Validation Accuracy: 0.671800
# Epoch 14, CIFAR-10 Batch 3:  Loss:      0.580 Validation Accuracy: 0.660400
# Epoch 14, CIFAR-10 Batch 4:  Loss:      0.537 Validation Accuracy: 0.666800
# Epoch 14, CIFAR-10 Batch 5:  Loss:      0.547 Validation Accuracy: 0.661000
# Epoch 15, CIFAR-10 Batch 1:  Loss:      0.638 Validation Accuracy: 0.673800
# Epoch 15, CIFAR-10 Batch 2:  Loss:      0.591 Validation Accuracy: 0.661000
# Epoch 15, CIFAR-10 Batch 3:  Loss:      0.538 Validation Accuracy: 0.666800
# Epoch 15, CIFAR-10 Batch 4:  Loss:      0.505 Validation Accuracy: 0.664200
# Epoch 15, CIFAR-10 Batch 5:  Loss:      0.512 Validation Accuracy: 0.670400
# Epoch 16, CIFAR-10 Batch 1:  Loss:      0.606 Validation Accuracy: 0.681800
# Epoch 16, CIFAR-10 Batch 2:  Loss:      0.551 Validation Accuracy: 0.671000
# Epoch 16, CIFAR-10 Batch 3:  Loss:      0.516 Validation Accuracy: 0.668000
# Epoch 16, CIFAR-10 Batch 4:  Loss:      0.485 Validation Accuracy: 0.678800
# Epoch 16, CIFAR-10 Batch 5:  Loss:      0.487 Validation Accuracy: 0.675600
# Epoch 17, CIFAR-10 Batch 1:  Loss:      0.560 Validation Accuracy: 0.684800
# Epoch 17, CIFAR-10 Batch 2:  Loss:      0.539 Validation Accuracy: 0.669800
# Epoch 17, CIFAR-10 Batch 3:  Loss:      0.488 Validation Accuracy: 0.675200
# Epoch 17, CIFAR-10 Batch 4:  Loss:      0.439 Validation Accuracy: 0.677200
# Epoch 17, CIFAR-10 Batch 5:  Loss:      0.459 Validation Accuracy: 0.679800
# Epoch 18, CIFAR-10 Batch 1:  Loss:      0.526 Validation Accuracy: 0.683600
# Epoch 18, CIFAR-10 Batch 2:  Loss:      0.521 Validation Accuracy: 0.669600
# Epoch 18, CIFAR-10 Batch 3:  Loss:      0.467 Validation Accuracy: 0.673600
# Epoch 18, CIFAR-10 Batch 4:  Loss:      0.441 Validation Accuracy: 0.678200
# Epoch 18, CIFAR-10 Batch 5:  Loss:      0.469 Validation Accuracy: 0.680400
# Epoch 19, CIFAR-10 Batch 1:  Loss:      0.514 Validation Accuracy: 0.677600
# Epoch 19, CIFAR-10 Batch 2:  Loss:      0.498 Validation Accuracy: 0.669000
# Epoch 19, CIFAR-10 Batch 3:  Loss:      0.461 Validation Accuracy: 0.681200
# Epoch 19, CIFAR-10 Batch 4:  Loss:      0.418 Validation Accuracy: 0.678800
# Epoch 19, CIFAR-10 Batch 5:  Loss:      0.441 Validation Accuracy: 0.677800
# Epoch 20, CIFAR-10 Batch 1:  Loss:      0.514 Validation Accuracy: 0.664600
# Epoch 20, CIFAR-10 Batch 2:  Loss:      0.510 Validation Accuracy: 0.680000
# Epoch 20, CIFAR-10 Batch 3:  Loss:      0.418 Validation Accuracy: 0.681600
# Epoch 20, CIFAR-10 Batch 4:  Loss:      0.388 Validation Accuracy: 0.677000
# Epoch 20, CIFAR-10 Batch 5:  Loss:      0.457 Validation Accuracy: 0.675600
# Epoch 21, CIFAR-10 Batch 1:  Loss:      0.488 Validation Accuracy: 0.672600
# Epoch 21, CIFAR-10 Batch 2:  Loss:      0.469 Validation Accuracy: 0.672600
# Epoch 21, CIFAR-10 Batch 3:  Loss:      0.437 Validation Accuracy: 0.665800
# Epoch 21, CIFAR-10 Batch 4:  Loss:      0.393 Validation Accuracy: 0.687800
# Epoch 21, CIFAR-10 Batch 5:  Loss:      0.422 Validation Accuracy: 0.678600
# Epoch 22, CIFAR-10 Batch 1:  Loss:      0.460 Validation Accuracy: 0.685800
# Epoch 22, CIFAR-10 Batch 2:  Loss:      0.422 Validation Accuracy: 0.688000
# Epoch 22, CIFAR-10 Batch 3:  Loss:      0.431 Validation Accuracy: 0.673000
# Epoch 22, CIFAR-10 Batch 4:  Loss:      0.343 Validation Accuracy: 0.684600
# Epoch 22, CIFAR-10 Batch 5:  Loss:      0.377 Validation Accuracy: 0.682000
# Epoch 23, CIFAR-10 Batch 1:  Loss:      0.416 Validation Accuracy: 0.684200
# Epoch 23, CIFAR-10 Batch 2:  Loss:      0.394 Validation Accuracy: 0.693600
# Epoch 23, CIFAR-10 Batch 3:  Loss:      0.383 Validation Accuracy: 0.683200
# Epoch 23, CIFAR-10 Batch 4:  Loss:      0.337 Validation Accuracy: 0.684000
# Epoch 23, CIFAR-10 Batch 5:  Loss:      0.352 Validation Accuracy: 0.681200
# Epoch 24, CIFAR-10 Batch 1:  Loss:      0.394 Validation Accuracy: 0.686200
# Epoch 24, CIFAR-10 Batch 2:  Loss:      0.374 Validation Accuracy: 0.691400
# Epoch 24, CIFAR-10 Batch 3:  Loss:      0.362 Validation Accuracy: 0.682400
# Epoch 24, CIFAR-10 Batch 4:  Loss:      0.306 Validation Accuracy: 0.683000
# Epoch 24, CIFAR-10 Batch 5:  Loss:      0.343 Validation Accuracy: 0.684200
# Epoch 25, CIFAR-10 Batch 1:  Loss:      0.379 Validation Accuracy: 0.690400
# Epoch 25, CIFAR-10 Batch 2:  Loss:      0.347 Validation Accuracy: 0.692600
# Epoch 25, CIFAR-10 Batch 3:  Loss:      0.342 Validation Accuracy: 0.685600
# Epoch 25, CIFAR-10 Batch 4:  Loss:      0.304 Validation Accuracy: 0.686000
# Epoch 25, CIFAR-10 Batch 5:  Loss:      0.322 Validation Accuracy: 0.683200
# Epoch 26, CIFAR-10 Batch 1:  Loss:      0.378 Validation Accuracy: 0.685600
# Epoch 26, CIFAR-10 Batch 2:  Loss:      0.348 Validation Accuracy: 0.689400
# Epoch 26, CIFAR-10 Batch 3:  Loss:      0.338 Validation Accuracy: 0.683400
# Epoch 26, CIFAR-10 Batch 4:  Loss:      0.272 Validation Accuracy: 0.687200
# Epoch 26, CIFAR-10 Batch 5:  Loss:      0.299 Validation Accuracy: 0.685800
# Epoch 27, CIFAR-10 Batch 1:  Loss:      0.339 Validation Accuracy: 0.690200
# Epoch 27, CIFAR-10 Batch 2:  Loss:      0.323 Validation Accuracy: 0.694400
# Epoch 27, CIFAR-10 Batch 3:  Loss:      0.316 Validation Accuracy: 0.686600
# Epoch 27, CIFAR-10 Batch 4:  Loss:      0.254 Validation Accuracy: 0.687400
# Epoch 27, CIFAR-10 Batch 5:  Loss:      0.286 Validation Accuracy: 0.692400
# Epoch 28, CIFAR-10 Batch 1:  Loss:      0.324 Validation Accuracy: 0.690800
# Epoch 28, CIFAR-10 Batch 2:  Loss:      0.302 Validation Accuracy: 0.694200
# Epoch 28, CIFAR-10 Batch 3:  Loss:      0.289 Validation Accuracy: 0.696000
# Epoch 28, CIFAR-10 Batch 4:  Loss:      0.261 Validation Accuracy: 0.697200
# Epoch 28, CIFAR-10 Batch 5:  Loss:      0.269 Validation Accuracy: 0.689200
# Epoch 29, CIFAR-10 Batch 1:  Loss:      0.313 Validation Accuracy: 0.696000
# Epoch 29, CIFAR-10 Batch 2:  Loss:      0.292 Validation Accuracy: 0.694200
# Epoch 29, CIFAR-10 Batch 3:  Loss:      0.296 Validation Accuracy: 0.690600
# Epoch 29, CIFAR-10 Batch 4:  Loss:      0.254 Validation Accuracy: 0.692200
# Epoch 29, CIFAR-10 Batch 5:  Loss:      0.263 Validation Accuracy: 0.686800
# Epoch 30, CIFAR-10 Batch 1:  Loss:      0.292 Validation Accuracy: 0.699000
# Epoch 30, CIFAR-10 Batch 2:  Loss:      0.269 Validation Accuracy: 0.698800
# Epoch 30, CIFAR-10 Batch 3:  Loss:      0.269 Validation Accuracy: 0.693200
# Epoch 30, CIFAR-10 Batch 4:  Loss:      0.229 Validation Accuracy: 0.693400
# Epoch 30, CIFAR-10 Batch 5:  Loss:      0.245 Validation Accuracy: 0.692400
# Epoch 31, CIFAR-10 Batch 1:  Loss:      0.280 Validation Accuracy: 0.691800
# Epoch 31, CIFAR-10 Batch 2:  Loss:      0.255 Validation Accuracy: 0.693400
# Epoch 31, CIFAR-10 Batch 3:  Loss:      0.253 Validation Accuracy: 0.693600
# Epoch 31, CIFAR-10 Batch 4:  Loss:      0.236 Validation Accuracy: 0.678000
# Epoch 31, CIFAR-10 Batch 5:  Loss:      0.216 Validation Accuracy: 0.693200
# Epoch 32, CIFAR-10 Batch 1:  Loss:      0.257 Validation Accuracy: 0.699600
# Epoch 32, CIFAR-10 Batch 2:  Loss:      0.245 Validation Accuracy: 0.690000
# Epoch 32, CIFAR-10 Batch 3:  Loss:      0.254 Validation Accuracy: 0.693000
# Epoch 32, CIFAR-10 Batch 4:  Loss:      0.210 Validation Accuracy: 0.689600
# Epoch 32, CIFAR-10 Batch 5:  Loss:      0.224 Validation Accuracy: 0.683600
# Epoch 33, CIFAR-10 Batch 1:  Loss:      0.265 Validation Accuracy: 0.692600
# Epoch 33, CIFAR-10 Batch 2:  Loss:      0.235 Validation Accuracy: 0.696800
# Epoch 33, CIFAR-10 Batch 3:  Loss:      0.221 Validation Accuracy: 0.694200
# Epoch 33, CIFAR-10 Batch 4:  Loss:      0.205 Validation Accuracy: 0.688000
# Epoch 33, CIFAR-10 Batch 5:  Loss:      0.219 Validation Accuracy: 0.687800
# Epoch 34, CIFAR-10 Batch 1:  Loss:      0.254 Validation Accuracy: 0.694200
# Epoch 34, CIFAR-10 Batch 2:  Loss:      0.217 Validation Accuracy: 0.691200
# Epoch 34, CIFAR-10 Batch 3:  Loss:      0.238 Validation Accuracy: 0.679400
# Epoch 34, CIFAR-10 Batch 4:  Loss:      0.205 Validation Accuracy: 0.692600
# Epoch 34, CIFAR-10 Batch 5:  Loss:      0.207 Validation Accuracy: 0.683800
# Epoch 35, CIFAR-10 Batch 1:  Loss:      0.217 Validation Accuracy: 0.699400
# Epoch 35, CIFAR-10 Batch 2:  Loss:      0.239 Validation Accuracy: 0.697200
# Epoch 35, CIFAR-10 Batch 3:  Loss:      0.207 Validation Accuracy: 0.688000
# Epoch 35, CIFAR-10 Batch 4:  Loss:      0.216 Validation Accuracy: 0.688200
# Epoch 35, CIFAR-10 Batch 5:  Loss:      0.209 Validation Accuracy: 0.682000
# Epoch 36, CIFAR-10 Batch 1:  Loss:      0.207 Validation Accuracy: 0.691800
# Epoch 36, CIFAR-10 Batch 2:  Loss:      0.203 Validation Accuracy: 0.697400
# Epoch 36, CIFAR-10 Batch 3:  Loss:      0.208 Validation Accuracy: 0.684800
# Epoch 36, CIFAR-10 Batch 4:  Loss:      0.167 Validation Accuracy: 0.693600
# Epoch 36, CIFAR-10 Batch 5:  Loss:      0.202 Validation Accuracy: 0.690600
# Epoch 37, CIFAR-10 Batch 1:  Loss:      0.204 Validation Accuracy: 0.695200
# Epoch 37, CIFAR-10 Batch 2:  Loss:      0.185 Validation Accuracy: 0.696000
# Epoch 37, CIFAR-10 Batch 3:  Loss:      0.191 Validation Accuracy: 0.689600
# Epoch 37, CIFAR-10 Batch 4:  Loss:      0.167 Validation Accuracy: 0.693000
# Epoch 37, CIFAR-10 Batch 5:  Loss:      0.186 Validation Accuracy: 0.682200
# Epoch 38, CIFAR-10 Batch 1:  Loss:      0.216 Validation Accuracy: 0.698200
# Epoch 38, CIFAR-10 Batch 2:  Loss:      0.175 Validation Accuracy: 0.699600
# Epoch 38, CIFAR-10 Batch 3:  Loss:      0.197 Validation Accuracy: 0.684600
# Epoch 38, CIFAR-10 Batch 4:  Loss:      0.154 Validation Accuracy: 0.690200
# Epoch 38, CIFAR-10 Batch 5:  Loss:      0.169 Validation Accuracy: 0.694600
# Epoch 39, CIFAR-10 Batch 1:  Loss:      0.183 Validation Accuracy: 0.698400
# Epoch 39, CIFAR-10 Batch 2:  Loss:      0.172 Validation Accuracy: 0.699600
# Epoch 39, CIFAR-10 Batch 3:  Loss:      0.173 Validation Accuracy: 0.684200
# Epoch 39, CIFAR-10 Batch 4:  Loss:      0.155 Validation Accuracy: 0.691200
# Epoch 39, CIFAR-10 Batch 5:  Loss:      0.169 Validation Accuracy: 0.680800
# Epoch 40, CIFAR-10 Batch 1:  Loss:      0.165 Validation Accuracy: 0.696600
# Epoch 40, CIFAR-10 Batch 2:  Loss:      0.182 Validation Accuracy: 0.696000
# Epoch 40, CIFAR-10 Batch 3:  Loss:      0.156 Validation Accuracy: 0.687600
# Epoch 40, CIFAR-10 Batch 4:  Loss:      0.139 Validation Accuracy: 0.682000
# Epoch 40, CIFAR-10 Batch 5:  Loss:      0.174 Validation Accuracy: 0.687600
# Epoch 41, CIFAR-10 Batch 1:  Loss:      0.157 Validation Accuracy: 0.692200
# Epoch 41, CIFAR-10 Batch 2:  Loss:      0.184 Validation Accuracy: 0.690800
# Epoch 41, CIFAR-10 Batch 3:  Loss:      0.164 Validation Accuracy: 0.693200
# Epoch 41, CIFAR-10 Batch 4:  Loss:      0.119 Validation Accuracy: 0.685200
# Epoch 41, CIFAR-10 Batch 5:  Loss:      0.148 Validation Accuracy: 0.692400
# Epoch 42, CIFAR-10 Batch 1:  Loss:      0.166 Validation Accuracy: 0.694800
# Epoch 42, CIFAR-10 Batch 2:  Loss:      0.166 Validation Accuracy: 0.697800
# Epoch 42, CIFAR-10 Batch 3:  Loss:      0.150 Validation Accuracy: 0.692200
# Epoch 42, CIFAR-10 Batch 4:  Loss:      0.123 Validation Accuracy: 0.683800
# Epoch 42, CIFAR-10 Batch 5:  Loss:      0.133 Validation Accuracy: 0.693400
# Epoch 43, CIFAR-10 Batch 1:  Loss:      0.156 Validation Accuracy: 0.701000
# Epoch 43, CIFAR-10 Batch 2:  Loss:      0.155 Validation Accuracy: 0.699200
# Epoch 43, CIFAR-10 Batch 3:  Loss:      0.150 Validation Accuracy: 0.690800
# Epoch 43, CIFAR-10 Batch 4:  Loss:      0.103 Validation Accuracy: 0.687000
# Epoch 43, CIFAR-10 Batch 5:  Loss:      0.116 Validation Accuracy: 0.692400
# Epoch 44, CIFAR-10 Batch 1:  Loss:      0.156 Validation Accuracy: 0.691200
# Epoch 44, CIFAR-10 Batch 2:  Loss:      0.145 Validation Accuracy: 0.692800
# Epoch 44, CIFAR-10 Batch 3:  Loss:      0.141 Validation Accuracy: 0.688600
# Epoch 44, CIFAR-10 Batch 4:  Loss:      0.103 Validation Accuracy: 0.687600
# Epoch 44, CIFAR-10 Batch 5:  Loss:      0.106 Validation Accuracy: 0.693600
# Epoch 45, CIFAR-10 Batch 1:  Loss:      0.144 Validation Accuracy: 0.692600
# Epoch 45, CIFAR-10 Batch 2:  Loss:      0.140 Validation Accuracy: 0.694600
# Epoch 45, CIFAR-10 Batch 3:  Loss:      0.147 Validation Accuracy: 0.688800
# Epoch 45, CIFAR-10 Batch 4:  Loss:      0.105 Validation Accuracy: 0.684600
# Epoch 45, CIFAR-10 Batch 5:  Loss:      0.125 Validation Accuracy: 0.683000
# Epoch 46, CIFAR-10 Batch 1:  Loss:      0.148 Validation Accuracy: 0.691000
# Epoch 46, CIFAR-10 Batch 2:  Loss:      0.136 Validation Accuracy: 0.691800
# Epoch 46, CIFAR-10 Batch 3:  Loss:      0.128 Validation Accuracy: 0.685000
# Epoch 46, CIFAR-10 Batch 4:  Loss:      0.092 Validation Accuracy: 0.689000
# Epoch 46, CIFAR-10 Batch 5:  Loss:      0.091 Validation Accuracy: 0.683000
# Epoch 47, CIFAR-10 Batch 1:  Loss:      0.131 Validation Accuracy: 0.694800
# Epoch 47, CIFAR-10 Batch 2:  Loss:      0.137 Validation Accuracy: 0.695800
# Epoch 47, CIFAR-10 Batch 3:  Loss:      0.120 Validation Accuracy: 0.691800
# Epoch 47, CIFAR-10 Batch 4:  Loss:      0.083 Validation Accuracy: 0.692600
# Epoch 47, CIFAR-10 Batch 5:  Loss:      0.090 Validation Accuracy: 0.691600
# Epoch 48, CIFAR-10 Batch 1:  Loss:      0.131 Validation Accuracy: 0.696000
# Epoch 48, CIFAR-10 Batch 2:  Loss:      0.123 Validation Accuracy: 0.695000
# Epoch 48, CIFAR-10 Batch 3:  Loss:      0.108 Validation Accuracy: 0.692400
# Epoch 48, CIFAR-10 Batch 4:  Loss:      0.075 Validation Accuracy: 0.694400
# Epoch 48, CIFAR-10 Batch 5:  Loss:      0.081 Validation Accuracy: 0.689200
# Epoch 49, CIFAR-10 Batch 1:  Loss:      0.130 Validation Accuracy: 0.687400
# Epoch 49, CIFAR-10 Batch 2:  Loss:      0.127 Validation Accuracy: 0.689800
# Epoch 49, CIFAR-10 Batch 3:  Loss:      0.109 Validation Accuracy: 0.690400
# Epoch 49, CIFAR-10 Batch 4:  Loss:      0.070 Validation Accuracy: 0.696000
# Epoch 49, CIFAR-10 Batch 5:  Loss:      0.078 Validation Accuracy: 0.694600
# Epoch 50, CIFAR-10 Batch 1:  Loss:      0.117 Validation Accuracy: 0.691400
# Epoch 50, CIFAR-10 Batch 2:  Loss:      0.119 Validation Accuracy: 0.696000
# Epoch 50, CIFAR-10 Batch 3:  Loss:      0.097 Validation Accuracy: 0.692400
# Epoch 50, CIFAR-10 Batch 4:  Loss:      0.064 Validation Accuracy: 0.692000
# Epoch 50, CIFAR-10 Batch 5:  Loss:      0.089 Validation Accuracy: 0.690000

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6940602034330368

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
